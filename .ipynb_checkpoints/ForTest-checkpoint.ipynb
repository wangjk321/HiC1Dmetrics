# %%
import sys
sys.path.append("/Users/wangjiankang/Google 云端硬盘/2013to2019_Macbook/DRFproject/github_HiC1Dmetrics/HiC1Dmetrics/MainCode")
from calculateMetrics import *
from plotMetrics import *

# %%
ss =SeparationScore("test_data/Control_1/observed.KR.chr21.matrix.gz",25000,"chr21")

# %%
Tss =ss.getTADss()

# %%
Tss.head(800)
# Out:
#        chr     start       end  SeparationScore
# 0    chr21         0     25000         0.000000
# 1    chr21     25000     50000         0.000000
# 2    chr21     50000     75000         0.000000
# 3    chr21     75000    100000         0.000000
# 4    chr21    100000    125000         0.000000
# ..     ...       ...       ...              ...
# 795  chr21  19875000  19900000         0.416741
# 796  chr21  19900000  19925000         0.413923
# 797  chr21  19925000  19950000         0.413985
# 798  chr21  19950000  19975000         0.410214
# 799  chr21  19975000  20000000         0.410410
#
# [800 rows x 4 columns]

# %%
PlotBedGraph("test_data/Control_1/observed.KR.chr21.matrix.gz",25000,startSite=27500000,endSite=32500000,chr="chr21",clmax=50).draw("DLR")
